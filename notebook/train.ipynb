# %%
# !pip install clearml
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 40.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.1 MB/s eta 0:00:00
# ...

# %%
# @title Insert your own Credentials

from clearml import Task

web_server = "https://app.clear.ml"  # @param {type:"string"}
api_server = "https://api.clear.ml"  # @param {type:"string"}
files_server = "https://files.clear.ml"  # @param {type:"string"}
access_key = ""
secret_key = ""

Task.set_credentials(
    web_host=web_server,
    api_host=api_server,
    files_host=files_server,
    key=access_key,
    secret=secret_key,
)

# %%
from clearml import Task, Dataset, OutputModel
import os
from ultralytics import YOLO

# 1. Init ClearML task
task = Task.init(project_name="fin-analyser", task_name="yolo")
task.execute_remotely(queue_name="gpu", clone=True)
# 2. Get the versioned dataset (no re-download if already local)
dataset = Dataset.get(dataset_id="d0a71c53f6834a6cb5761d0894936aa6")
data_path = dataset.get_local_copy()
yaml_path = os.path.join(data_path, "data.yaml")

# 3. Select model and hyperparams
model_variant = "yolov8n"
task.set_parameter("model_variant", model_variant)
model = YOLO(f"{model_variant}.pt")

# 4. Define args (note the "name" so checkpoints go to runs/train/fin_run)
args = {
    "data": yaml_path,
    "device": 0,
    "batch": 16,
    "epochs": 200,
    "name": "fin_run_1",  # ← make sure you give it a run name
}
task.connect(args)

# 5. Train
results = model.train(**args)

# 6. Upload artifacts
best_pt = os.path.join("runs", "train", args["name"], "weights", "best.pt")
last_pt = os.path.join("runs", "train", args["name"], "weights", "last.pt")
task.upload_artifact(name="yolo_best", artifact_object=best_pt)
task.upload_artifact(name="yolo_last", artifact_object=last_pt)

output_model = OutputModel(
    task=task,
    framework="PyTorch",  # specify your framework
    name="yolov8-fin-v1",  # how it appears in the registry
    comment="YOLOv8 fine-tuned",  # optional: { "class1":0, ... }
    config_dict=args,  # optional: store your hyperparameters/config
)
# now attach the actual weights
output_model.update_weights(best_pt)
# Out:
# ClearML Task: created new task id=0efbd9bf77c041b2b5abe62ae6dab955
# 2025-06-30 21:13:53,157 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.clear.ml/projects/771e1a6c585c4305846050f5f3e77368/experiments/0efbd9bf77c041b2b5abe62ae6dab955/output/log
# 2025-06-30 21:13:59,210 - clearml - INFO - Dataset.get() did not specify alias. Dataset information will not be automatically logged in ClearML Server.
# 2025-06-30 21:14:05,887 - clearml.storage - INFO - Downloading: 45.41MB from https://files.clear.ml/YOLOv8/.datasets/fin-data/fin-data.d0a71c53f6834a6cb5761d0894936aa6/artifacts/data/dataset.d0a71c53f6834a6cb5761d0894936aa6.2ufzwz1k.zip
# ██████████████████████████████▋  99% | 45.00/45.41 MB [00:00<00:00, 45.36MB/s]: /usr/local/lib/python3.11/dist-packages/tqdm/std.py:636: TqdmWarning:
#
# clamping frac to range [0, 1]
#
# ███████████████████████████████ 100% | 45.41/45.41 MB [00:00<00:00, 48.43MB/s]:
# ...
